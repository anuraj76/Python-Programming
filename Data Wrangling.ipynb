# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('SalaryGender.csv')

# %%
salary = np.array(df['Salary'])

# %%
gender = np.array(df['Gender'])

# %%
Phd = np.array(df['PhD'])

# %%
age = np.array(df['Age'])

# %%
df
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %% [markdown]
# Data Exploration techniques

# %%
#Dimenasionality Check

df.shape
# Out:
# (100, 4)

# %%
#Type od Dataset

print(type(df))
df['Salary'].dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# dtype('float64')

# %%
#Slicing and Indexing

List = [1,2,3,4,5,6]

List[1:4]
# Out:
# [2, 3, 4]

# %%
#Perfrom slicing using iloc Indexer

df.iloc[1:15,1:3]
# Out:
#     Gender  Age
# 1        0   65
# 2        0   56
# 3        1   23
# 4        0   53
# 5        0   27
# 6        1   53
# 7        0   30
# 8        1   44
# 9        1   63
# 10       1   22
# 11       1   59
# 12       1   60
# 13       1   28
# 14       1   65

# %%
#Identify unique elements

df['Age'].unique()
# Out:
# array([47, 65, 56, 23, 53, 27, 30, 44, 63, 22, 59, 60, 28, 25, 66, 45, 46,
#        24, 36, 51, 52, 54, 26, 49, 34, 58, 77, 67, 48, 32, 43, 61, 29, 62,
#        41, 57, 71, 20, 69, 37, 33, 42, 55], dtype=int64)

# %%
#Extracting Values

df['Age'].values
# Out:
# array([47, 65, 56, 23, 53, 27, 53, 30, 44, 63, 22, 59, 60, 28, 65, 25, 65,
#        47, 66, 45, 46, 24, 60, 63, 27, 66, 36, 30, 51, 65, 45, 52, 54, 30,
#        52, 26, 49, 22, 34, 60, 28, 58, 77, 67, 27, 48, 45, 49, 36, 65, 32,
#        49, 67, 22, 49, 43, 61, 43, 52, 51, 66, 29, 62, 56, 61, 56, 41, 24,
#        60, 43, 57, 23, 53, 71, 20, 27, 69, 58, 37, 32, 33, 32, 60, 71, 30,
#        62, 54, 42, 62, 51, 71, 29, 55, 54, 55, 26, 56, 28, 44, 24],
#       dtype=int64)

# %%
df['Age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     47
# 1     65
# 2     56
# 3     23
# 4     53
#       ..
# 95    26
# 96    56
# 97    28
# 98    44
# 99    24
# Name: Age, Length: 100, dtype: int64>

# %%
#Feature Median

df.median()
# Out:
# Salary    39.3
# Gender     0.5
# Age       49.0
# PhD        0.0
# dtype: float64

# %% [markdown]
# Correlation Analysis

# %%
df = pd.read_csv('middle_tn_schools.csv')

# %%
df['state_percentile_15'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 342    False
# 343    False
# 344    False
# 345    False
# 346    False
# Name: state_percentile_15, Length: 347, dtype: bool

# %%
df.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
#Group by School rating for Reduced lunch

df[['reduced_lunch','school_rating']].groupby(['school_rating']).describe().unstack()
# Out:
#                       school_rating
# reduced_lunch  count  0.0              43.000000
#                       1.0              40.000000
#                       2.0              44.000000
#                       3.0              56.000000
#                       4.0              86.000000
#                       5.0              78.000000
#                mean   0.0              83.581395
#                       1.0              74.950000
#                       2.0              64.272727
#                       3.0              50.285714
#                       4.0              41.000000
#                       5.0              21.602564
#                std    0.0               8.813498
#                       1.0              11.644191
#                       2.0              11.956051
#                       3.0              13.550866
#                       4.0              16.681092
#                       5.0              17.651268
# ...

# %%
df[['reduced_lunch','school_rating']].corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %%
#Data Wrangling

#1.Missing Values in Dataset

df.isna().any()
# Out:
# name                   False
# school_rating          False
# size                   False
# reduced_lunch          False
# state_percentile_16    False
# state_percentile_15     True
# stu_teach_ratio        False
# school_type            False
# avg_score_15            True
# avg_score_16           False
# full_time_teachers     False
# percent_black          False
# percent_white          False
# percent_asian          False
# percent_hispanic       False
# dtype: bool

# %%
#Mean Imputation

from sklearn.preprocessing import Imputer

# %%
mean_imputer = Imputer(missing_values = np.nan,strategy = 'mean',axis = 1)

# %%
State15 = mean_imputer.fit(df)

# %%
mean_imputer
# Out:
# Imputer(axis=1, copy=True, missing_values=nan, strategy='mean', verbose=0)

# %%
df
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
df['state_percentile_15'].head(50)
# Out:
# 0     95.8
# 1     37.3
# 2     83.6
# 3      1.0
# 4     89.2
# 5     76.4
# 6     74.6
# 7     93.4
# 8     77.9
# 9     55.5
# 10     2.9
# 11    63.8
# 12    62.8
# 13    90.3
# 14    66.2
# 15    87.1
# 16    54.1
# 17    59.2
# 18    92.4
# 19    13.9
# 20    97.3
# 21    98.2
# 22    82.5
# 23    83.9
# 24     0.8
# 25    55.5
# 26    18.7
# 27     3.9
# 28    16.0
# 29     NaN
# 30    46.2
# 31    10.5
# 32    61.2
# 33    81.2
# 34    79.8
# 35    91.6
# 36    12.9
# 37    89.6
# 38    14.0
# 39    63.2
# 40    90.0
# 41    99.6
# 42    35.2
# 43    13.2
# 44    72.1
# 45    92.0
# 46    26.1
# 47    85.5
# 48    98.3
# 49    30.5
# Name: state_percentile_15, dtype: float64

# %%
#Outlier Detection and Treatment

# %%
import seaborn as sns
sns.boxplot(x=df['reduced_lunch'])

# %%
df
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
filter = df['state_percentile_15'].values>85
# Out:
# C:\Users\asm1318\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
df_filtered = df[filter]

# %%
df_filtered
# Out:
#                             name  school_rating    size  reduced_lunch  \
# 0    Allendale Elementary School            5.0   851.0           10.0
# 4            Barfield Elementary            4.0   948.0           26.0
# 7               Beech Elementary            5.0   612.0           16.0
# 13    Blackman Elementary School            5.0   880.0           25.0
# 15        Blackman Middle School            4.0  1212.0           30.0
# ..                           ...            ...     ...            ...
# 319        Washington Elementary            4.0   449.0           48.0
# 332   Westwood Elementary School            4.0   550.0           40.0
# 341     Wilson Elementary School            4.0   800.0           25.0
# 343   Winstead Elementary School            5.0   515.0            8.0
# 345       Woodland Middle School            5.0   866.0            2.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio school_type  \
# ...
