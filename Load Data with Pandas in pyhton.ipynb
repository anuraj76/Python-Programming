# %%
# !pip install xlrd

# %%
import pandas as pd

# %%
df = pd.read_excel('Global Superstore.xls')

# %%
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
x = df[['State']]
x
# Out:
#                  State
# 0             New York
# 1      New South Wales
# 2           Queensland
# 3               Berlin
# 4                Dakar
# ...                ...
# 51285        Hiroshima
# 51286            Texas
# 51287       California
# 51288        São Paulo
# 51289          Managua
#
# [51290 rows x 1 columns]

# %%
x = type(df[['City']])
x
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
y = df[['State','City','Segment']]
y
# Out:
#                  State           City      Segment
# 0             New York  New York City     Consumer
# 1      New South Wales     Wollongong    Corporate
# 2           Queensland       Brisbane     Consumer
# 3               Berlin         Berlin  Home Office
# 4                Dakar          Dakar     Consumer
# ...                ...            ...          ...
# 51285        Hiroshima           Kure    Corporate
# 51286            Texas        Houston     Consumer
# 51287       California         Oxnard  Home Office
# 51288        São Paulo       Valinhos  Home Office
# 51289          Managua       Tipitapa     Consumer
#
# [51290 rows x 3 columns]

# %%
df.iloc[0, 0]
# Out:
# 32298

# %%
df.iloc[1,0]
# Out:
# 26341

# %%
df.loc[0, 'State']
# Out:
# 'New York'

# %%
df.loc[1, 'City']
# Out:
# 'Wollongong'

# %%
df.iloc[0:2, 0:3]
# Out:
#    Row ID        Order ID Order Date
# 0   32298  CA-2012-124891 2012-07-31
# 1   26341   IN-2013-77878 2013-02-05

# %%
df.loc[0:2, 'State':'Product Name']
# Out:
#              State        Country  Postal Code Market   Region  \
# 0         New York  United States      10024.0     US     East
# 1  New South Wales      Australia          NaN   APAC  Oceania
# 2       Queensland      Australia          NaN   APAC  Oceania
#
#         Product ID    Category Sub-Category  \
# 0  TEC-AC-10003033  Technology  Accessories
# 1  FUR-CH-10003950   Furniture       Chairs
# 2  TEC-PH-10004664  Technology       Phones
#
#                                         Product Name
# 0  Plantronics CS510 - Over-the-Head monaural Wir...
# 1          Novimex Executive Leather Armchair, Black
# 2                  Nokia Smart Phone, with Caller ID

# %% [markdown]
# *Quiz on DataFrame

# %% [markdown]
# Use a variable q to store the column Market as a dataframe

# %%
q = df[['Market']]

# %%
q
# Out:
#        Market
# 0          US
# 1        APAC
# 2        APAC
# 3          EU
# 4      Africa
# ...       ...
# 51285    APAC
# 51286      US
# 51287      US
# 51288   LATAM
# 51289   LATAM
#
# [51290 rows x 1 columns]

# %%
q = df[['State','Market']]
q
# Out:
#                  State  Market
# 0             New York      US
# 1      New South Wales    APAC
# 2           Queensland    APAC
# 3               Berlin      EU
# 4                Dakar  Africa
# ...                ...     ...
# 51285        Hiroshima    APAC
# 51286            Texas      US
# 51287       California      US
# 51288        São Paulo   LATAM
# 51289          Managua   LATAM
#
# [51290 rows x 2 columns]

# %%
df.iloc[1,2]
# Out:
# Timestamp('2013-02-05 00:00:00')
