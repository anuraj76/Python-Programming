# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
print('Setup complete')
# Out:
# Setup complete

# %%
California_data = pd.read_excel('California_housing.xlsx')

# %%
df_California_data = pd.DataFrame(California_data)

# %%
df_California_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
sns.scatterplot(x=df_California_data['total_rooms'],y=df_California_data['median_house_value'],hue=df_California_data['housing_median_age'])

# %%
df_Comcast = pd.DataFrame(pd.read_csv('Comcast_telecom_complaints_data.csv',index_col='Date',parse_dates=True))

# %%
df_Comcast
# Out:
#            Ticket #                                 Customer Complaint  \
# Date
# 2015-04-22   250635                      Comcast Cable Internet Speeds
# 2015-04-08   223441       Payment disappear - service got disconnected
# 2015-04-18   242732                                  Speed and Service
# 2015-05-07   277946  Comcast Imposed a New Usage Cap of 300GB that ...
# 2015-05-26   307175         Comcast not working and no service to boot
# ...             ...                                                ...
# 2015-04-02   213550                               Service Availability
# 2015-06-02   318775         Comcast Monthly Billing for Returned Modem
# 2015-06-09   331188                            complaint about comcast
# 2015-06-23   360489             Extremely unsatisfied Comcast customer
# 2015-06-24   363614               Comcast, Ypsilanti MI Internet Speed
#
#            Date_month_year         Time        Received Via        City  \
# Date
# ...

# %%
df_Comcast.head()
# Out:
#            Ticket #                                 Customer Complaint  \
# Date
# 2015-04-22   250635                      Comcast Cable Internet Speeds
# 2015-04-08   223441       Payment disappear - service got disconnected
# 2015-04-18   242732                                  Speed and Service
# 2015-05-07   277946  Comcast Imposed a New Usage Cap of 300GB that ...
# 2015-05-26   307175         Comcast not working and no service to boot
#
#            Date_month_year         Time        Received Via      City  \
# Date
# 2015-04-22       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon
# 2015-04-08       04-Aug-15  10:22:56 AM            Internet   Acworth
# 2015-04-18       18-Apr-15   9:55:47 AM            Internet   Acworth
# 2015-05-07       05-Jul-15  11:59:35 AM            Internet   Acworth
# 2015-05-26       26-May-15   1:25:26 PM            Internet   Acworth
#
#                State  Zip code  Status Filing on Behalf of Someone
# Date
# ...

# %%
# Load Data for Museums

df_museums = pd.DataFrame(pd.read_csv('LA_museum_visitors.csv',index_col='Date',parse_dates=True))

# %%
df_museums.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %% [markdown]
# plt.figure(figsize=(16,4))
# sns.lineplot(data=df_museums)

# %%
plt.figure(figsize=(16,4))
plt.title('Comparision of Fire Museum and Avila Adobe')
sns.lineplot(data=df_museums['Avila Adobe'],label='Avila Adobe')
sns.lineplot(data=df_museums['Firehouse Museum'],label='Firehouse Museum')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
#Bar Charts and Heat Maps

# %%
df_flightsdelays = pd.DataFrame(pd.read_csv('datasets_116573_334386_flight_delays.csv',index_col='Month'))

# %%
df_flightsdelays
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
# Bar chart for  average arrival delay for Spirit Airlines (airline code: NK) flights, by month.

# %%
plt.figure(figsize=(16,4))
plt.title('Avergare Arrival Flight Delay for Spirit Airways, by Month')
sns.barplot(x=df_flightsdelays.index,y=df_flightsdelays['NK'])
plt.ylabel('Delay in Mins')
# Out:
# Text(0, 0.5, 'Delay in Mins')

# %%
#Plottype - HeatMap

# %%
plt.figure(figsize=(16,7))
plt.title('Avg Arrival delay for each Airline, by Month')
sns.heatmap(data=df_flightsdelays, annot=True)
plt.xlabel('Airline')
# Out:
# Text(0.5, 42.0, 'Airline')

# %%
# PLot a scatter plot

# %%
df_insurance = pd.DataFrame(pd.read_csv('insurance.csv'))

# %%
df_insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x=df_insurance['bmi'],y=df_insurance['charges'])

# %%
sns.regplot(x=df_insurance['bmi'],y=df_insurance['charges'])

# %%
sns.scatterplot(x=df_insurance['bmi'],y=df_insurance['charges'],hue=df_insurance['smoker'])

# %%
sns.lmplot(x='bmi',y='charges',hue='smoker',data=df_insurance)

# %%
sns.swarmplot(x=df_insurance['smoker'],y=df_insurance['charges'])

# %%
# Histogram

# %%
df_iris = pd.DataFrame(pd.read_csv('iris.csv',index_col='Id'))

# %%
df_iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.distplot(a=df_iris['Petal Length (cm)'])

# %%
# Density plot

sns.kdeplot(data=df_iris['Petal Length (cm)'],shade=True)

# %%
#2D KDE Plot

# %%
sns.jointplot(x=df_iris['Petal Length (cm)'],y=df_iris['Sepal Width (cm)'],kind='kde')

# %%
#Histogram for each species
